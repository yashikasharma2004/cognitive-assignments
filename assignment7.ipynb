# %%
'''Q1. You are a data analyst at an e-commerce company. Your task is to analyze sales data,
clean and process it, perform staƟsƟcal analysis, and generate visual insights to help the
business make informed decisions.
1. Use your roll number as the random seed to generate unique data for each student.
2. Follow the quesƟons step by step, as each part builds upon the previous one.
3. Submit the assignment as a Jupyter Notebook (.ipynb) with:
 Well-documented code and clear comments.
 Markdown explanaƟons for each step.
 Screenshots of the plots and outputs. '''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


'''Part I: Randomized Sales Data GeneraƟon (NumPy)
1. IniƟalize Random Seed
2. Generate Sales Data
 Create a NumPy array of random sales data for 12 months (shape = (12, 4)),
where each column represents a product category:
 Electronics, Clothing, Home & Kitchen, Sports.
 Sales values should be between 1000 and 5000 units per month.
 The range should be randomized using the seed.
3. Convert to DataFrame
 Convert the cleaned NumPy array into a Pandas DataFrame with:
i. Columns: Electronics, Clothing, Home & Kitchen, Sports
ii. Index: Months from Jan to Dec '''
# part 1 randomized sales data generation


# 1 intialize random seed
roll_no=102317089
np.random.seed(roll_no)

# 2.generates sales data
sales_data=np.random.randint(1000,5000,size=(12,4))

# 3. convert to data frame
months=['January','February','March','April','May','June','July','August','September','October','November','December']
categories=['electronics','clothing','home and kitchen','sports']
sales_df=pd.DataFrame(sales_data,columns=categories, index=months)


'''Part II: Data ManipulaƟon and Analysis (Pandas)
1. Display the first 5 rows and summary staƟsƟcs of the DataFrame.
2. Calculate the total sales per category and total sales per month.
3. Calculate the average sales growth between consecuƟve months for each category.
4. Add the following columns to the DataFrame:
 Total Sales: Sum of all categories per month.
 Growth Rate: Percentage change in Total Sales from the previous month.
5. Apply a randomized discount:
 If your roll number is even, apply a 10% discount to the Electronics category.
 If odd, apply a 15% discount to the Clothing category '''
# part ii: data manipulation and analysis

#1. display the first 5 rows and summary statistics
print("first 5 rows of sales data:")
print(sales_df.head())
print("summary statistics:")
print(sales_df.describe())

#2. calculate total sales per category and total sales per month
total_sales_per_category=sales_df.sum()
total_sales_per_month=sales_df.sum(axis=1)

#3.average sales growth between consecutive months for each category
sales_growth=sales_df.pct_change().mean()*100

#4. add total sales and growth rate columns
sales_df['total_sales']=total_sales_per_month
sales_df['sales_growth']=sales_df['total_sales'].pct_change()*100

#5. apply a randomized discount
if roll_no %2==0:
            sales_df['electronics']*=0.90
else:
            sales_df['clothing']*=0.85

''' Part III: VisualizaƟons (Matplotlib and Seaborn)
1. Plot monthly sales trends for each category using line plots.
2. Create the following plots:
 Box plots to show the sales distribuƟon for each category'''

#part iii visualizations

#1. plot monthly sales trends
plt.figure(figsize=(10,6))
for category in categories:
            plt.plot(sales_df.index,sales_df[category],marker='o',label=category)
plt.xlabel('month')
plt.ylabel('sales')
plt.title('monthly sales trends')
plt.legend()
plt.show()


#2. box plots for sales distribution
plt.figure(figsize=(8,6))
sns.boxplot(data=sales_df[categories])
plt.title('sales distribution by category')
plt.ylabel('Sales')
plt.show()


#save the processed dataframe
sales_df.to_csv('sales_analysis.csv', index =True)
# Out:
# first 5 rows of sales data:
#           electronics  clothing  home and kitchen  sports
# January          4059      4236              1255    3770
# February         1789      4993              3636    3897
# March            1587      3983              2606    1502
# April            3864      2235              4302    1263
# May              4114      4280              3835    4901
# summary statistics:
#        electronics     clothing  home and kitchen       sports
# count    12.000000    12.000000         12.000000    12.000000
# mean   2530.166667  3781.333333       3016.916667  3121.416667
# std    1228.829290   950.416017       1185.196452  1338.137135
# min    1006.000000  2021.000000       1081.000000  1263.000000
# 25%    1495.750000  3466.750000       2346.250000  2220.500000
# 50%    2400.500000  3904.500000       2876.000000  3187.000000
# 75%    3912.750000  4335.000000       3946.250000  4043.750000
# max    4138.000000  4993.000000       4765.000000  4960.000000

# %%
'''Q.2 For the array: array = np.array([[1, -2, 3],[-4, 5, -6]])
 i. Find element-wise absolute value
ii. Find the 25th, 50th, and 75th percenƟle of flaƩened array, for each column, for each
row.
iii. Mean, Median and Standard DeviaƟon of flaƩened array, of each column, and
each row '''

array=np.array([[1,-2,3],[-4,5,6]])
# i. element wise absolute value
absolute_values=np.abs(array)
print("element wise absolute value:\n",absolute_values)

#ii. compile percentiles
percentiles_flat=np.percentile(array,[25,50,75])
percentiles_col=np.percentile(array,[25,50,75],axis=0)
percentiles_row=np.percentile(array,[25,50,75],axis=1)

print("\nPercentiles (Flattened Array - 25th, 50th, 75th):\n", percentiles_flat)
print("\nPercentiles (Per Column - 25th, 50th, 75th):\n", percentiles_col)
print("\nPercentiles (Per Row - 25th, 50th, 75th):\n", percentiles_row)



#iii. compute mean,median, standard deviation
mean_flat=np.mean(array)
median_flat=np.median(array)
std_flat=np.std(array)

mean_col=np.mean(array,axis=0)
median_col=np.median(array,axis=0)
std_col=np.std(array,axis=0)

mean_row=np.mean(array,axis=1)
median_row=np.median(array,axis=1)
std_row=np.std(array,axis=1)


print("\nMean, Median, and Standard Deviation (Flattened):")
print(f"Mean: {mean_flat}, Median: {median_flat}, Standard Deviation: {std_flat}")

print("\nMean, Median, and Standard Deviation (Per Column):")
print(f"Mean: {mean_col}, Median: {median_col}, Standard Deviation: {std_col}")

print("\nMean, Median, and Standard Deviation (Per Row):")
print(f"Mean: {mean_row}, Median: {median_row}, Standard Deviation: {std_row}")
# Out:
# element wise absolute value:
#  [[1 2 3]
#  [4 5 6]]
#
# Percentiles (Flattened Array - 25th, 50th, 75th):
#  [-1.25  2.    4.5 ]
#
# Percentiles (Per Column - 25th, 50th, 75th):
#  [[-2.75 -0.25  3.75]
#  [-1.5   1.5   4.5 ]
#  [-0.25  3.25  5.25]]
#
# Percentiles (Per Row - 25th, 50th, 75th):
#  [[-0.5  0.5]
#  [ 1.   5. ]
#  [ 2.   5.5]]
#
# Mean, Median, and Standard Deviation (Flattened):
# Mean: 1.5, Median: 2.0, Standard Deviation: 3.593976442141304
#
# Mean, Median, and Standard Deviation (Per Column):
# Mean: [-1.5  1.5  4.5], Median: [-1.5  1.5  4.5], Standard Deviation: [2.5 3.5 1.5]
#
# Mean, Median, and Standard Deviation (Per Row):
# Mean: [0.66666667 2.33333333], Median: [1. 5.], Standard Deviation: [2.05480467 4.49691252]

# %%
'''Q.3 For the array: a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0]).
 i. Find floor, ceiling and truncated value, rounded values '''

a=np.array([-1.8,-1.6,-0.5,0.5,1.6,1.8,3.0])
# i. Compute floor, ceiling, truncation, and rounded values
floor_values = np.floor(a)
ceiling_values = np.ceil(a)
truncated_values = np.trunc(a)
rounded_values = np.round(a)

# Display results
print("Original array:", a)
print("Floor values:", floor_values)
print("Ceiling values:", ceiling_values)
print("Truncated values:", truncated_values)
print("Rounded values:", rounded_values)
# Out:
# Original array: [-1.8 -1.6 -0.5  0.5  1.6  1.8  3. ]
# Floor values: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling values: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated values: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded values: [-2. -2. -0.  0.  2.  2.  3.]

# %%
'''Q.4 WAP to swap two elements in a list in Python Using a Temporary Variable.'''
def swap_elements(lst, index1, index2):
  temp=lst[index1]
  lst[index1]=lst[index2]
  lst[index2]=temp

my_list=[10,20,30,40,50]

index1=1
index2=3
print("before swap",my_list)
swap_elements(my_list, index1, index2)
print("after swap",my_list)
# Out:
# before swap [10, 20, 30, 40, 50]
# after swap [10, 40, 30, 20, 50]

# %%
'''Q.5 Write a Python program to swap two elements in a set by converƟng it to a list first.'''


def swap_elements_in_set(s,elem1, elem2):
  if elem1 not in s or elem2 not in s:
    print("Both elements must be present in the set!")
    return s

  lst=list(s)
  index1 ,index2 =lst.index(elem1),lst.index(elem2)

  lst[index1],lst[index2]=lst[index2],lst[index1]

  return set(lst)

my_set={10,20,30,40,50}


elem1,elem2=20,40


print("Before swapping:", my_set)
swapped_set = swap_elements_in_set(my_set, elem1, elem2)
print("After swapping:", swapped_set)
# Out:
# Before swapping: {50, 20, 40, 10, 30}
# After swapping: {40, 10, 50, 20, 30}
